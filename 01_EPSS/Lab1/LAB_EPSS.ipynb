# %%
import pandas as pd
import os
import requests
import json
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# %%
from preprocessing_utils import preprocess_NVD_data

# %%
data_path = 'data'
if not os.path.exists(data_path):
    os.makedirs(data_path)

# %% [markdown]
# # EPSS data

# %% [markdown]
# Download the EPSS data from https://www.first.org/epss/data_stats into `data` folder

# %% [markdown]
# ### <font color='blue'><b><i>TODO</i></b></font>:
# - in the following cell, replace `epss_scores-2025-09-30.csv.gz` with the correct updated file (`epss_scores-2025-10-01.csv.gz`)

# %%
epss_current = pd.read_csv(os.path.join(data_path, 'epss_scores-2025-10-01.csv.gz'), compression='gzip', header=1)
epss_current # a Python statement with a variable name at the end of a cell will display its contents below
# Out:
#                   cve     epss  percentile
# 0       CVE-1999-0001  0.01141     0.77780
# 1       CVE-1999-0002  0.10742     0.93087
# 2       CVE-1999-0003  0.90362     0.99589
# 3       CVE-1999-0004  0.03215     0.86596
# 4       CVE-1999-0005  0.25334     0.96035
# ...               ...      ...         ...
# 296328  CVE-2025-9994  0.00060     0.19138
# 296329  CVE-2025-9996  0.00179     0.40027
# 296330  CVE-2025-9997  0.00182     0.40386
# 296331  CVE-2025-9998  0.00023     0.04753
# 296332  CVE-2025-9999  0.00040     0.11642
#
# [296333 rows x 3 columns]

# %% [markdown]
# # NVD data

# %%
base_url = "https://services.nvd.nist.gov/rest/json/cves/2.0"
date_start_NVD = '2025-09-01T00:00:00.000Z' # Do NOT change these dates
date_end_NVD   = '2025-10-01T00:00:00.000Z' # Do NOT change these dates
start_index = 0
results_per_page = 1000
total_results = 1 

all_cves = []

while start_index < total_results:
    params = {
        "pubStartDate": date_start_NVD,
        "pubEndDate": date_end_NVD,
        "resultsPerPage": results_per_page,
        "startIndex": start_index,
        "noRejected": ""
    }
    response = requests.get(base_url, params=params, timeout=6)
    if response.status_code != 200:
        print("Error:", response.status_code)
        break

    data = response.json()
    total_results = data.get("totalResults", 0)

    all_cves.extend(data.get("vulnerabilities", []))

    start_index += results_per_page
    print(start_index)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000

# %%
# normalize and preprocess data
df = pd.json_normalize(all_cves, record_path=None, sep='.', max_level=None)
df = preprocess_NVD_data(df)

# remove vulnerabilities marked as "reject" or "reserved"
df = df[(df['cve.vulnStatus']!='Reserved') & (df['cve.vulnStatus']!='Reject')]

# merge NVD and EPSS data
df = df.merge(epss_current, left_on="cve.id", right_on="cve", how="left")

# %%
# save nvd data
with open(os.path.join(data_path, "nvd_cves.json"), "w", encoding="utf-8") as f:
    json.dump(all_cves, f, indent=2)
    
# save the final dataframe
df.to_csv(os.path.join(data_path, "vuln_2025_09.csv"))

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# - display some examples (e.g., the first two CVE records)

# %%
df.head(20).T
# Out:
#                                                                            0   \
# cve.id                                                          CVE-2025-9751
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 00:15:34.580000
# cve.lastModified                                   2025-09-08 14:06:05.217000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/HAO-RAY/HCR-CVE/i...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A weakness has been identified in Campcodes On...
# vulnerable_cpes             [cpe:2.3:a:campcodes:online_learning_managemen...
# num_references                                                              6
# cwe_list                                             [CWE-74, CWE-89, CWE-89]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            9.8
# cvss_baseSeverity                                                    CRITICAL
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                             CVE-2025-9751
# epss                                                                   0.0003
# percentile                                                            0.07395
#
#                                                                            1   \
# cve.id                                                          CVE-2025-9752
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 01:15:46.817000
# cve.lastModified                                   2025-09-04 18:47:25.440000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/i-Corner/cve/issu...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A security vulnerability has been detected in ...
# vulnerable_cpes             [cpe:2.3:o:dlink:dir-852_firmware:1.00cn_b09:*...
# num_references                                                              6
# cwe_list                                             [CWE-77, CWE-78, CWE-78]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            9.8
# cvss_baseSeverity                                                    CRITICAL
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                             CVE-2025-9752
# epss                                                                  0.00242
# percentile                                                            0.47575
#
#                                                                            2   \
# cve.id                                                          CVE-2025-9753
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 01:15:47.060000
# cve.lastModified                                   2025-09-04 18:46:50.757000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/Yashh-G/zero-day-...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A vulnerability was detected in Campcodes Onli...
# vulnerable_cpes             [cpe:2.3:a:campcodes:online_hospital_managemen...
# num_references                                                              5
# cwe_list                                                     [CWE-79, CWE-94]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:H/UI:R/S:C/C:L/I:L/A:N
# cvss_baseScore                                                            4.8
# cvss_baseSeverity                                                      MEDIUM
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  HIGH
# cvss_userInteraction                                                 REQUIRED
# cvss_scope                                                            CHANGED
# cvss_confidentialityImpact                                                LOW
# cvss_integrityImpact                                                      LOW
# cvss_availabilityImpact                                                  NONE
# cve                                                             CVE-2025-9753
# epss                                                                  0.00026
# percentile                                                            0.05727
#
#                                                                            3   \
# cve.id                                                          CVE-2025-9754
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 02:15:45.223000
# cve.lastModified                                   2025-09-04 18:46:58.453000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/Yashh-G/zero-day-...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A flaw has been found in Campcodes Online Hosp...
# vulnerable_cpes             [cpe:2.3:a:campcodes:online_hospital_managemen...
# num_references                                                              5
# cwe_list                                                     [CWE-79, CWE-94]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:L/UI:R/S:C/C:L/I:L/A:N
# cvss_baseScore                                                            5.4
# cvss_baseSeverity                                                      MEDIUM
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                   LOW
# cvss_userInteraction                                                 REQUIRED
# cvss_scope                                                            CHANGED
# cvss_confidentialityImpact                                                LOW
# cvss_integrityImpact                                                      LOW
# cvss_availabilityImpact                                                  NONE
# cve                                                             CVE-2025-9754
# epss                                                                  0.00028
# percentile                                                            0.06386
#
#                                                                            4   \
# cve.id                                                          CVE-2025-9755
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 02:15:45.493000
# cve.lastModified                                   2025-09-05 19:54:52.480000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://gist.github.com/0xSebin/147e...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A vulnerability has been found in Khanakag-17 ...
# vulnerable_cpes             [cpe:2.3:a:khanakag-17:library_management_syst...
# num_references                                                              5
# cwe_list                                             [CWE-79, CWE-94, CWE-79]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:C/C:L/I:L/A:N
# cvss_baseScore                                                            6.1
# cvss_baseSeverity                                                      MEDIUM
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                 REQUIRED
# cvss_scope                                                            CHANGED
# cvss_confidentialityImpact                                                LOW
# cvss_integrityImpact                                                      LOW
# cvss_availabilityImpact                                                  NONE
# cve                                                             CVE-2025-9755
# epss                                                                  0.00028
# percentile                                                            0.06393
#
#                                                                            5   \
# cve.id                                                          CVE-2025-9756
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 02:15:45.713000
# cve.lastModified                                   2025-09-08 14:02:39.200000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/CSentinel/CVE/iss...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A vulnerability was found in PHPGurukul User M...
# vulnerable_cpes             [cpe:2.3:a:phpgurukul:user_management_system:1...
# num_references                                                              6
# cwe_list                                             [CWE-74, CWE-89, CWE-89]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            8.8
# cvss_baseSeverity                                                        HIGH
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                   LOW
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                             CVE-2025-9756
# epss                                                                  0.00028
# percentile                                                            0.06611
#
#                                                                            6   \
# cve.id                                                          CVE-2025-9567
# cve.sourceIdentifier                                       twcert@cert.org.tw
# cve.published                                      2025-09-01 03:15:32.337000
# cve.lastModified                                   2025-09-25 14:18:08.317000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://www.twcert.org.tw/en/cp-139-...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 The eHRD developed by Sunnet has a Reflected C...
# vulnerable_cpes                 [cpe:2.3:a:sun.net:ehrd_ctms:-:*:*:*:*:*:*:*]
# num_references                                                              2
# cwe_list                                                             [CWE-79]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:C/C:L/I:L/A:N
# cvss_baseScore                                                            6.1
# cvss_baseSeverity                                                      MEDIUM
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                 REQUIRED
# cvss_scope                                                            CHANGED
# cvss_confidentialityImpact                                                LOW
# cvss_integrityImpact                                                      LOW
# cvss_availabilityImpact                                                  NONE
# cve                                                             CVE-2025-9567
# epss                                                                  0.00047
# percentile                                                            0.14213
#
#                                                                            7   \
# cve.id                                                          CVE-2025-9568
# cve.sourceIdentifier                                       twcert@cert.org.tw
# cve.published                                      2025-09-01 03:15:32.570000
# cve.lastModified                                   2025-09-25 14:18:31.453000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://www.twcert.org.tw/en/cp-139-...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 The eHRD developed by Sunnet has a Reflected C...
# vulnerable_cpes                 [cpe:2.3:a:sun.net:ehrd_ctms:-:*:*:*:*:*:*:*]
# num_references                                                              2
# cwe_list                                                             [CWE-79]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:C/C:L/I:L/A:N
# cvss_baseScore                                                            6.1
# cvss_baseSeverity                                                      MEDIUM
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                 REQUIRED
# cvss_scope                                                            CHANGED
# cvss_confidentialityImpact                                                LOW
# cvss_integrityImpact                                                      LOW
# cvss_availabilityImpact                                                  NONE
# cve                                                             CVE-2025-9568
# epss                                                                  0.00047
# percentile                                                            0.14213
#
#                                                                            8   \
# cve.id                                                          CVE-2025-9569
# cve.sourceIdentifier                                       twcert@cert.org.tw
# cve.published                                      2025-09-01 03:15:32.767000
# cve.lastModified                                   2025-09-25 14:18:03.243000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://www.twcert.org.tw/en/cp-139-...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 The eHRD developed by Sunnet has a Reflected C...
# vulnerable_cpes                 [cpe:2.3:a:sun.net:ehrd_ctms:-:*:*:*:*:*:*:*]
# num_references                                                              2
# cwe_list                                                             [CWE-79]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:C/C:L/I:L/A:N
# cvss_baseScore                                                            6.1
# cvss_baseSeverity                                                      MEDIUM
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                 REQUIRED
# cvss_scope                                                            CHANGED
# cvss_confidentialityImpact                                                LOW
# cvss_integrityImpact                                                      LOW
# cvss_availabilityImpact                                                  NONE
# cve                                                             CVE-2025-9569
# epss                                                                  0.00047
# percentile                                                            0.14213
#
#                                                                            9   \
# cve.id                                                          CVE-2025-9757
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 03:15:32.967000
# cve.lastModified                                   2025-09-08 13:54:13.633000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/lrjbsyh/CVE_Hunte...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A vulnerability was determined in Campcodes/So...
# vulnerable_cpes             [cpe:2.3:a:campcodes:courier_management_system...
# num_references                                                              6
# cwe_list                                             [CWE-74, CWE-89, CWE-89]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            9.8
# cvss_baseSeverity                                                    CRITICAL
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                             CVE-2025-9757
# epss                                                                   0.0003
# percentile                                                            0.07395
#
#                                                                            10  \
# cve.id                                                          CVE-2025-7405
# cve.sourceIdentifier        Mitsubishielectric.Psirt@yd.MitsubishiElectric...
# cve.published                                      2025-09-01 04:15:45.110000
# cve.lastModified                                   2025-09-02 15:55:25.420000
# cve.vulnStatus                                              Awaiting Analysis
# cve.references              [{'url': 'https://jvn.jp/vu/JVNVU90041458/', '...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 Missing Authentication for Critical Function v...
# vulnerable_cpes                                                            []
# num_references                                                              3
# cwe_list                                                            [CWE-306]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:L/A:L
# cvss_baseScore                                                            7.3
# cvss_baseSeverity                                                        HIGH
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                                LOW
# cvss_integrityImpact                                                      LOW
# cvss_availabilityImpact                                                   LOW
# cve                                                             CVE-2025-7405
# epss                                                                  0.00219
# percentile                                                            0.44706
#
#                                                                            11  \
# cve.id                                                          CVE-2025-7731
# cve.sourceIdentifier        Mitsubishielectric.Psirt@yd.MitsubishiElectric...
# cve.published                                      2025-09-01 04:15:51.357000
# cve.lastModified                                   2025-09-02 15:55:25.420000
# cve.vulnStatus                                              Awaiting Analysis
# cve.references              [{'url': 'https://jvn.jp/vu/JVNVU90041458/', '...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 Cleartext Transmission of Sensitive Informatio...
# vulnerable_cpes                                                            []
# num_references                                                              3
# cwe_list                                                            [CWE-319]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:N/A:N
# cvss_baseScore                                                            7.5
# cvss_baseSeverity                                                        HIGH
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     NONE
# cvss_availabilityImpact                                                  NONE
# cve                                                             CVE-2025-7731
# epss                                                                  0.00016
# percentile                                                            0.02464
#
#                                                                            12  \
# cve.id                                                          CVE-2025-9570
# cve.sourceIdentifier                                       twcert@cert.org.tw
# cve.published                                      2025-09-01 04:15:51.600000
# cve.lastModified                                   2025-09-25 14:18:25.953000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://www.twcert.org.tw/en/cp-139-...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 The eHRD CTMS developed by Sunnet has an Arbit...
# vulnerable_cpes                 [cpe:2.3:a:sun.net:ehrd_ctms:-:*:*:*:*:*:*:*]
# num_references                                                              2
# cwe_list                                                             [CWE-23]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:H/UI:N/S:U/C:H/I:N/A:N
# cvss_baseScore                                                            4.9
# cvss_baseSeverity                                                      MEDIUM
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  HIGH
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     NONE
# cvss_availabilityImpact                                                  NONE
# cve                                                             CVE-2025-9570
# epss                                                                  0.00062
# percentile                                                            0.19733
#
#                                                                            13  \
# cve.id                                                          CVE-2025-9758
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 04:15:51.843000
# cve.lastModified                                   2025-09-11 21:16:26.307000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://gist.github.com/0xSebin/29cb...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A vulnerability was identified in deepakmisal2...
# vulnerable_cpes             [cpe:2.3:a:deepakmisal24:chemical_inventory_ma...
# num_references                                                              7
# cwe_list                                             [CWE-74, CWE-89, CWE-89]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            9.8
# cvss_baseSeverity                                                    CRITICAL
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                             CVE-2025-9758
# epss                                                                  0.00028
# percentile                                                            0.06611
#
#                                                                            14  \
# cve.id                                                          CVE-2025-9759
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 04:15:53.650000
# cve.lastModified                                   2025-09-08 13:53:29.567000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/lrjbsyh/CVE_Hunte...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A security flaw has been discovered in Campcod...
# vulnerable_cpes             [cpe:2.3:a:campcodes:courier_management_system...
# num_references                                                              5
# cwe_list                                             [CWE-74, CWE-89, CWE-89]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            9.8
# cvss_baseSeverity                                                    CRITICAL
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                             CVE-2025-9759
# epss                                                                   0.0003
# percentile                                                            0.07395
#
#                                                                            15  \
# cve.id                                                          CVE-2025-9760
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 05:15:41.997000
# cve.lastModified                                   2025-09-27 00:28:31.297000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/marcelomulder/CVE...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A weakness has been identified in Portabilis i...
# vulnerable_cpes               [cpe:2.3:a:portabilis:i-educar:*:*:*:*:*:*:*:*]
# num_references                                                              8
# cwe_list                                                   [CWE-266, CWE-285]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            8.8
# cvss_baseSeverity                                                        HIGH
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                   LOW
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                             CVE-2025-9760
# epss                                                                  0.00048
# percentile                                                            0.14565
#
#                                                                            16  \
# cve.id                                                          CVE-2025-9761
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 05:15:42.863000
# cve.lastModified                                   2025-09-08 13:45:56.043000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/HAO-RAY/HCR-CVE/i...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A security vulnerability has been detected in ...
# vulnerable_cpes             [cpe:2.3:a:campcodes:online_feeds_product_inve...
# num_references                                                              6
# cwe_list                                             [CWE-74, CWE-89, CWE-89]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            9.8
# cvss_baseSeverity                                                    CRITICAL
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                             CVE-2025-9761
# epss                                                                   0.0003
# percentile                                                            0.07395
#
#                                                                            17  \
# cve.id                                                          CVE-2025-9763
# cve.sourceIdentifier                                            cna@vuldb.com
# cve.published                                      2025-09-01 05:15:43.090000
# cve.lastModified                                   2025-09-08 13:40:09.430000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://github.com/gggg6886/CVE/issu...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 A vulnerability was detected in Campcodes Onli...
# vulnerable_cpes             [cpe:2.3:a:campcodes:online_learning_managemen...
# num_references                                                              6
# cwe_list                                             [CWE-74, CWE-89, CWE-89]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            9.8
# cvss_baseSeverity                                                    CRITICAL
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                             CVE-2025-9763
# epss                                                                   0.0003
# percentile                                                            0.07395
#
#                                                                            18  \
# cve.id                                                         CVE-2025-20703
# cve.sourceIdentifier                                    security@mediatek.com
# cve.published                                      2025-09-01 06:15:33.357000
# cve.lastModified                                   2025-09-03 16:07:38.867000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://corp.mediatek.com/product-se...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 In Modem, there is a possible out of bounds re...
# vulnerable_cpes             [cpe:2.3:o:mediatek:nr15:-:*:*:*:*:*:*:*, cpe:...
# num_references                                                              1
# cwe_list                                                            [CWE-125]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:H
# cvss_baseScore                                                            7.5
# cvss_baseSeverity                                                        HIGH
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                     NONE
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               NONE
# cvss_integrityImpact                                                     NONE
# cvss_availabilityImpact                                                  HIGH
# cve                                                            CVE-2025-20703
# epss                                                                  0.00278
# percentile                                                            0.51085
#
#                                                                            19
# cve.id                                                         CVE-2025-20704
# cve.sourceIdentifier                                    security@mediatek.com
# cve.published                                      2025-09-01 06:15:34.630000
# cve.lastModified                                   2025-09-03 16:07:22.770000
# cve.vulnStatus                                                       Analyzed
# cve.references              [{'url': 'https://corp.mediatek.com/product-se...
# cve.cisaExploitAdd                                                        NaN
# cve.cisaActionDue                                                         NaN
# cve.cisaRequiredAction                                                    NaN
# cve.cisaVulnerabilityName                                                 NaN
# description                 In Modem, there is a possible out of bounds wr...
# vulnerable_cpes             [cpe:2.3:o:mediatek:nr17:-:*:*:*:*:*:*:*, cpe:...
# num_references                                                              1
# cwe_list                                                            [CWE-787]
# cvss_version                                                              3.1
# cvss_vectorString                CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H
# cvss_baseScore                                                            8.8
# cvss_baseSeverity                                                        HIGH
# cvss_attackVector                                                     NETWORK
# cvss_attackComplexity                                                     LOW
# cvss_privilegesRequired                                                  NONE
# cvss_userInteraction                                                 REQUIRED
# cvss_scope                                                          UNCHANGED
# cvss_confidentialityImpact                                               HIGH
# cvss_integrityImpact                                                     HIGH
# cvss_availabilityImpact                                                  HIGH
# cve                                                            CVE-2025-20704
# epss                                                                  0.00198
# percentile                                                            0.42262

# %% [markdown]
# - show a bar plot with the daily volume of published CVEs

# %%
published_counts = df["cve.published"].dt.date.value_counts().sort_index()

print(published_counts)

plt.figure(figsize=(12, 5))
sns.barplot(x=published_counts.index, y=published_counts.values, color="k" )
plt.xticks(rotation=90)
plt.xlabel("Date")
plt.ylabel("Number of CVEs Published")
plt.title("CVE Publications per Day")
plt.tight_layout()
plt.show()
# Out:
# cve.published
# 2025-09-01     84
# 2025-09-02    136
# 2025-09-03    184
# 2025-09-04    276
# 2025-09-05    235
# 2025-09-06     61
# 2025-09-07     17
# 2025-09-08     92
# 2025-09-09    351
# 2025-09-10     96
# 2025-09-11    155
# 2025-09-12     93
# 2025-09-13     15
# 2025-09-14     35
# 2025-09-15    409
# 2025-09-16    232
# 2025-09-17    216
# 2025-09-18    200
# 2025-09-19    121
# 2025-09-20     14
# 2025-09-21     17
# 2025-09-22    416
# 2025-09-23    128
# 2025-09-24    125
# 2025-09-25    107
# 2025-09-26    200
# 2025-09-27     52
# 2025-09-28     36
# 2025-09-29    114
# 2025-09-30    109
# Name: count, dtype: int64
# C:\Users\franc\AppData\Local\Temp\ipykernel_21360\4033208350.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4326 entries, 0 to 4325
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cve.id                      4326 non-null   object
#  1   cve.sourceIdentifier        4326 non-null   object
#  2   cve.published               4326 non-null   datetime64[ns]
#  3   cve.lastModified            4326 non-null   datetime64[ns]
#  4   cve.vulnStatus              4326 non-null   object
#  5   cve.references              4326 non-null   object
#  6   cve.cisaExploitAdd          9 non-null      object
#  7   cve.cisaActionDue           9 non-null      object
#  8   cve.cisaRequiredAction      9 non-null      object
#  9   cve.cisaVulnerabilityName   9 non-null      object
#  10  description                 4326 non-null   object
#  11  vulnerable_cpes             4326 non-null   object
#  12  num_references              4326 non-null   int64
#  13  cwe_list                    4326 non-null   object
#  14  cvss_version                3343 non-null   object
#  15  cvss_vectorString           3343 non-null   object
#  16  cvss_baseScore              3343 non-null   float64
#  17  cvss_baseSeverity           3343 non-null   category
#  18  cvss_attackVector           3343 non-null   object
#  19  cvss_attackComplexity       3343 non-null   object
#  20  cvss_privilegesRequired     3343 non-null   object
#  21  cvss_userInteraction        3343 non-null   object
#  22  cvss_scope                  3343 non-null   object
#  23  cvss_confidentialityImpact  3343 non-null   object
#  24  cvss_integrityImpact        3343 non-null   object
#  25  cvss_availabilityImpact     3343 non-null   object
#  26  cve                         4326 non-null   object
#  27  epss                        4326 non-null   float64
#  28  percentile                  4326 non-null   float64
# dtypes: category(1), datetime64[ns](2), float64(3), int64(1), object(22)
# memory usage: 950.9+ KB

# %% [markdown]
# - print the description of the last ten published vulnerabilities

# %%
for idx, x in enumerate(df.sort_values('cve.published', ascending=False)[:10].iterrows()):
    print('-'*100)
    print(x[1]['cve.id'], x[1]['cve.published'])
    print(x[1].description)
# Out:
# ----------------------------------------------------------------------------------------------------
# CVE-2025-61792 2025-09-30 23:15:29.700000
# Quadient DS-700 iQ devices through 2025-09-30 might have a race condition during the quick clicking of (in order) the Question Mark button, the Help Button, the About button, and the Help Button, leading to a transition out of kiosk mode into local administrative access. NOTE: the reporter indicates that the "behavior was observed sporadically" during "limited time on the client site," making it not "possible to gain more information about the specific kiosk mode crashing issue," and the only conclusion was "there appears to be some form of race condition." Accordingly, there can be doubt that a reproducible cybersecurity vulnerability was identified; sporadic software crashes can also be caused by a hardware fault on a single device (for example, transient RAM errors). The reporter also describes a variety of other issues, including initial access via USB because of the absence of a "lock-pick resistant locking solution for the External Controller PC cabinet," which is not a cybersecurity vulnerability (section 4.1.5 of the CNA Operational Rules). Finally, it is unclear whether the device or OS configuration was inappropriate, given that the risks are typically limited to insider threats within the mail operations room of a large company.
# ----------------------------------------------------------------------------------------------------
# CVE-2025-55191 2025-09-30 23:15:29.533000
# Argo CD is a declarative, GitOps continuous delivery tool for Kubernetes. Versions between 2.1.0 and 2.14.19, 3.2.0-rc1, 3.1.0-rc1 through 3.1.7, and 3.0.0-rc1 through 3.0.18 contain a race condition in the repository credentials handler that can cause the Argo CD server to panic and crash when concurrent operations are performed on the same repository URL. The vulnerability is located in numerous repository related handlers in the util/db/repository_secrets.go file. A valid API token with repositories resource permissions (create, update, or delete actions) is required to trigger the race condition. This vulnerability causes the entire Argo CD server to crash and become unavailable. Attackers can repeatedly and continuously trigger the race condition to maintain a denial-of-service state, disrupting all GitOps operations. This issue is fixed in versions 2.14.20, 3.2.0-rc2, 3.1.8 and 3.0.19.
# ----------------------------------------------------------------------------------------------------
# CVE-2025-43826 2025-09-30 23:15:29.160000
# Stored cross-site scripting (XSS) vulnerabilities in Web Content translation in Liferay Portal 7.4.0 through 7.4.3.112, and older unsupported versions, and Liferay DXP 2023.Q4.0 through 2023.Q4.8, 2023.Q3.1 through 2023.Q3.10, 7.4 GA through update 92, and older unsupported versions allow remote attackers to inject arbitrary web script or HTML via any rich text field in a web content article.
# ----------------------------------------------------------------------------------------------------
# CVE-2025-24525 2025-09-30 23:15:27.970000
# Keysight Ixia Vision has an issue with hardcoded cryptographic material
# which may allow an attacker to intercept or decrypt payloads sent to the
#  device via API calls or user authentication if the end user does not
# replace the TLS certificate that shipped with the device. Remediation is
#  available in Version 6.9.1, released on September 23, 2025.
# ----------------------------------------------------------------------------------------------------
# CVE-2025-56392 2025-09-30 20:15:39.997000
# An Insecure Direct Object Reference (IDOR) in the /dashboard/notes endpoint of Syaqui Collegetivity v1.0.0 allows attackers to impersonate other users and perform arbitrary operations via a crafted POST request.
# ----------------------------------------------------------------------------------------------------
# CVE-2025-36262 2025-09-30 20:15:37.993000
# IBM Planning Analytics Local 2.0.0 through 2.0.106 and 2.1.0 through 2.1.13
#
# could allow a malicious privileged user to bypass the UI to gain unauthorized access to sensitive information due to the improper validation of input.
# ----------------------------------------------------------------------------------------------------
# CVE-2025-36132 2025-09-30 20:15:37.810000
# IBM Planning Analytics Local 2.0.0 through 2.0.106 and 2.1.0 through 2.1.13 is vulnerable to cross-site scripting. This vulnerability allows an authenticated user to embed arbitrary JavaScript code in the Web UI thus altering the intended functionality potentially leading to credentials disclosure within a trusted session.
# ----------------------------------------------------------------------------------------------------
# CVE-2025-10659 2025-09-30 20:15:36.450000
# The Telenium Online Web Application is vulnerable due to a PHP endpoint accessible to unauthenticated network users that improperly handles user-supplied input. This vulnerability occurs due to the insecure termination of a regular expression check within the endpoint. Because the input is not correctly validated or sanitized, an unauthenticated attacker can inject arbitrary operating system commands through a crafted HTTP request, leading to remote code execution on the server in the context of the web application service account.
# ----------------------------------------------------------------------------------------------------
# CVE-2024-55017 2025-09-30 20:15:36.100000
# Account Takeover in Corezoid 6.6.0 in the OAuth2 implementation via an open redirect in the redirect_uri parameter allows attackers to intercept authorization codes and gain unauthorized access to victim accounts.
# ----------------------------------------------------------------------------------------------------
# CVE-2025-56132 2025-09-30 19:15:37.253000
# LiquidFiles filetransfer server is vulnerable to a user enumeration issue in its password reset functionality. The application returns distinguishable responses for valid and invalid email addresses, allowing unauthenticated attackers to determine the existence of user accounts. Version 4.2 introduces user-based lockout mechanisms to mitigate brute-force attacks, user enumeration remains possible by default. In versions prior to 4.2, no such user-level protection is in place, only basic IP-based rate limiting is enforced. This IP-based protection can be bypassed by distributing requests across multiple IPs (e.g., rotating IP or proxies). Effectively bypassing both login and password reset security controls. Successful exploitation allows an attacker to enumerate valid email addresses registered for the application, increasing the risk of follow-up attacks such as password spraying.

# %% [markdown]
# ### <font color='blue'><b><i>TODO</i></b>: produce plots or tables to address the folowing points</font>
# - what is the percentage of CVEs which received a CVSS score?
# - report descriptive statistics of CVSS the CVSS base score and/or show its distribution
# - report descriptive statistics of EPSS and/or show its distribution
# - produce a scatter plot showing CVSS vs EPSS
# - <b>be creative</b>!
#     - How many vulnerabilities are published on CISA KEV?
#     - What are the the 20 most frequent vendors? (vendor name can be extracted from the `vulnerable_cpes` field).
#     - What are the 20 most frequent CWEs?
#     - Anaything else you see fit!
#
# <font color='blue'>Use text cells to discuss the outcome after each point</font>

# %%
# plotting precentage of CVEs which received a CVSS score

total_CVEs = len(df)
cves_with_CVEs = len(df[df['cvss_baseScore'].notna()])

percentage_CVEs_with_CVSS = cves_with_CVEs / total_CVEs * 100

print(f"Total percentage CVEs with CVSS score = {percentage_CVEs_with_CVSS:.2f}%")
# Out:
# Total percentage CVEs with CVSS score = 77.28%

# %%
# report descriptive statistics of CVSS the CVSS base score and/or show its distribution

print("CVSS Statistics:")
print(df['cvss_baseScore'].describe())

# desired index order
desired_order = ['Low (0.0-3.9)', 'Medium (4.0-6.9)', 'High (7.0-8.9)', 'Critical (9.0-10.0)']

# Create CVSS severity categories
def categorize_cvss(score):
    if 0.0 <= score <= 3.9:
        return 'Low (0.0-3.9)'
    elif 4.0 <= score <= 6.9:
        return 'Medium (4.0-6.9)'
    elif 7.0 <= score <= 8.9:
        return 'High (7.0-8.9)'
    elif 9.0 <= score <= 10.0:
        return 'Critical (9.0-10.0)'
    else:
        return 'Unknown'

# Apply categorization
df['cvss_category'] = df['cvss_baseScore'].apply(categorize_cvss)

# Count by category
category_counts = df['cvss_category'].value_counts()

# Reindex the category_counts with the desired order
category_counts_ordered = category_counts.reindex(desired_order)

# Remove any NaN values (categories that don't exist in your data)
category_counts_ordered = category_counts_ordered.dropna()

print(category_counts_ordered)

colors = ['green', 'yellow', 'orange', 'red']

plt.figure(figsize=(12, 5))
sns.barplot(x=category_counts_ordered.index, y=category_counts_ordered.values, 
           palette = colors, 
           edgecolor="grey", 
           linewidth=1.5)     
plt.xticks(rotation=0)
plt.xlabel("CVSS value")
plt.ylabel("Number of CVEs")
plt.title("CVSS analysis")
plt.tight_layout()
plt.show()

#plt.pie(data = category_counts_ordered.index, labels = category_counts_ordered.values, colors = colors)
#plt.show()
# Out:
# CVSS Statistics:
# count    3343.000000
# mean        6.904696
# std         1.803809
# min         2.200000
# 25%         5.400000
# 50%         6.500000
# 75%         8.150000
# max        10.000000
# Name: cvss_baseScore, dtype: float64
# cvss_category
# Low (0.0-3.9)           120
# Medium (4.0-6.9)       1616
# High (7.0-8.9)         1113
# Critical (9.0-10.0)     494
# Name: count, dtype: int64
# C:\Users\franc\AppData\Local\Temp\ipykernel_21360\1912575591.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts_ordered.index, y=category_counts_ordered.values,
# C:\Users\franc\AppData\Local\Temp\ipykernel_21360\1912575591.py:48: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# report descriptive statistics of EPSS and/or show its distribution

print("EPSS Statistics:")
print(df['epss'].describe())

plt.figure(figsize=(12, 6))
plt.xlim(0, 0.002)
sns.histplot(df["epss"], color="blue", binrange=[0,0.003])
plt.xlabel("EPSS Value")
plt.ylabel("Quantity")
plt.title("Distribution of EPSS Values")
plt.show()
# Out:
# EPSS Statistics:
# count    4326.000000
# mean        0.001476
# std         0.017277
# min         0.000020
# 25%         0.000240
# 50%         0.000320
# 75%         0.000470
# max         0.810640
# Name: epss, dtype: float64
# C:\Users\franc\AppData\Local\Temp\ipykernel_21360\1887996290.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Create scatter plot showing CVSS vs EPSS

# Filter out missing values first
scatter_data = df.dropna(subset=['cvss_baseScore', 'epss', 'cvss_category'])

# Print basic statistics
print("EPSS Statistics:")
print(scatter_data['epss'].describe())

plt.figure(figsize=(12, 5))
sns.scatterplot(data=scatter_data,
                x='cvss_baseScore',
                y='epss', 
                hue='cvss_category',
                palette={'Low (0.0-3.9)': 'green', 
                        'Medium (4.0-6.9)': 'yellow', 
                        'High (7.0-8.9)': 'orange', 
                        'Critical (9.0-10.0)': 'red'},
                alpha=0.7,
                s=50)

plt.xlabel("CVSS Ver 3.1")
plt.ylabel("EPSS Score")
plt.title("CVSS vs EPSS Scatter Plot")
plt.legend(title='CVSS Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# EPSS Statistics:
# count    3343.000000
# mean        0.001752
# std         0.019635
# min         0.000020
# 25%         0.000260
# 50%         0.000340
# 75%         0.000490
# max         0.810640
# Name: epss, dtype: float64
# C:\Users\franc\AppData\Local\Temp\ipykernel_21360\271622152.py:27: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### CVSS vs EPSS Scatter Plot Analysis
#
# The scatter plot below shows the relationship between CVSS Base Score (x-axis) and EPSS Score (y-axis). This visualization helps us understand:
# - Whether higher CVSS scores correlate with higher exploitation probability (EPSS)
# - The distribution and clustering patterns of vulnerabilities
# - Outliers that might have high CVSS but low EPSS (or vice versa)

# %%
# Create scatter plot showing CVSS vs EPSS
plt.figure(figsize=(10, 6))

# Filter out rows where either CVSS or EPSS is missing
scatter_data = df.dropna(subset=['cvss_baseScore', 'epss'])

# Create the scatter plot
plt.scatter(scatter_data['cvss_baseScore'], scatter_data['epss'], 
           alpha=0.6, s=20, color='blue', edgecolors='black', linewidth=0.5)

plt.xlabel('CVSS Base Score')
plt.ylabel('EPSS Score')
plt.title('CVSS vs EPSS Scatter Plot')
plt.grid(True, alpha=0.3)

# Add some statistics
correlation = scatter_data['cvss_baseScore'].corr(scatter_data['epss'])
plt.text(0.05, 0.95, f'Correlation: {correlation:.3f}', 
         transform=plt.gca().transAxes, bbox=dict(boxstyle="round", facecolor='wheat'))

plt.tight_layout()
plt.show()

# Print some basic statistics
print(f"Number of CVEs with both CVSS and EPSS scores: {len(scatter_data)}")
print(f"Correlation between CVSS and EPSS: {correlation:.3f}")
print(f"CVSS range: {scatter_data['cvss_baseScore'].min():.1f} - {scatter_data['cvss_baseScore'].max():.1f}")
print(f"EPSS range: {scatter_data['epss'].min():.6f} - {scatter_data['epss'].max():.6f}")
# Out:
# Number of CVEs with both CVSS and EPSS scores: 3343
# Correlation between CVSS and EPSS: 0.058
# CVSS range: 2.2 - 10.0
# EPSS range: 0.000020 - 0.810640
# C:\Users\franc\AppData\Local\Temp\ipykernel_21360\135959685.py:22: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# # CVE selection

# %% [markdown]
# ### <font color='blue'><b><i>TODO</i></b>
# - Filter the CVEs with low EPSS (<1%)
# - Select candidate CVEs
#     - From the resulting subset, select 10 CVEs that you think will reach high EPSS by the end of the course.
#     - Clearly describe the criteria you used for selection (e.g., high CVSS, popular software, CWE, popular vendor, number of references, keyword in description, manual inspection, random sampling, security blogs).
# - Share the selected CVE ids with the instructor (by two weeks). Use the code cell below to produce the csv file to submit.
# - Track the EPSS of your CVEs over time
#
# # suggestion
# - Possibly we may want to leverage:
#     - threath intelligence systems are biased towards the sensor networks (ceratin types of vulns)
#     - probably the vuls affecting platforms on the perimetral of the networks are highly attractive for an attacker (intuition)
#         - defining "boundaries" is not simple
#     - this is in order to have more precision in our model

# %%
# filtering the EPSS with low score (<1%)

df_filtered = df.loc[df["epss"] < 0.01]
df_filtered_epss = df_filtered["epss"]

print(df_filtered_epss)
# Out:
# 0       0.00030
# 1       0.00242
# 2       0.00026
# 3       0.00028
# 4       0.00028
#          ...
# 4321    0.00018
# 4322    0.00027
# 4323    0.00150
# 4324    0.00028
# 4325    0.00017
# Name: epss, Length: 4268, dtype: float64

# %%
# sorting the dataset

df_totally_filtered = df_filtered[(df["num_references"]>6) & 
            (df["cvss_baseSeverity"]=="CRITICAL") & 
            (df["cvss_privilegesRequired"]=="NONE")]


# print("Before filtering the CWE:")
# print(df_test["cwe_list"])


def check_cwe_list(worst_cwe_list, cwe_list_to_check):
    i=0
    for element in worst_cwe_list:
        if element in cwe_list_to_check:
            break
        else:
            i=i+1
    if i==10:
        return False
    else:
        return True
        
def filtering_cwe_condition(list_of_all_cwe):
    bool_list_result = []
    worst_cwe_list = ["CWE-787", "CWE-843", "CWE-78", "CWE-94", "CWE-502", "CWE-22", "CWE-306", "CWE-89", "CWE-416", "CWE-77"]
    for element in list_of_all_cwe:
        result = check_cwe_list(worst_cwe_list=worst_cwe_list, cwe_list_to_check=element)
        bool_list_result.append(result)
    print(bool_list_result)
    return bool_list_result



df_totally_filtered_with_cwe = df_totally_filtered[(filtering_cwe_condition(df_totally_filtered["cwe_list"].values))]

# print("After filtering the CWE:")
# print(df_test["cwe_list"])

print(df_totally_filtered_with_cwe["cve.id"])
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_21360\2846955412.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_totally_filtered = df_filtered[(df["num_references"]>6) &
# [True, True, True, True, True, True, False, False, False, False, True, True, True, True, True, True, True, False]
# 13       CVE-2025-9758
# 69       CVE-2025-9789
# 71       CVE-2025-9791
# 76       CVE-2025-9794
# 160      CVE-2025-9829
# 1040    CVE-2025-10097
# 2860    CVE-2025-10687
# 3033    CVE-2025-10768
# 3034    CVE-2025-10769
# 3046    CVE-2025-10779
# 3056    CVE-2025-10785
# 3085    CVE-2025-10800
# 3439    CVE-2025-59528
# Name: cve.id, dtype: object

# %%
final_choice = df_totally_filtered_with_cwe["cve.id"].head(10)

print(final_choice)
# Out:
# 13       CVE-2025-9758
# 69       CVE-2025-9789
# 71       CVE-2025-9791
# 76       CVE-2025-9794
# 160      CVE-2025-9829
# 1040    CVE-2025-10097
# 2860    CVE-2025-10687
# 3033    CVE-2025-10768
# 3034    CVE-2025-10769
# 3046    CVE-2025-10779
# Name: cve.id, dtype: object

# %% [markdown]
# #priviledges required
# - set to NONE to have the least requirements

# %%
nickname = 'VisCount' # TODO: put your nickname here


# TODO: put your selected IDs here
selected = ['CVE-2025-9758',
            'CVE-2025-9789',
            'CVE-2025-9791',
            'CVE-2025-9794',
            'CVE-2025-9829',
            'CVE-2025-10097',
            'CVE-2025-10687',
            'CVE-2025-10768',
            'CVE-2025-10769',
            'CVE-2025-10779',
           ]            

df[df['cve.id'].isin(selected)].to_csv(os.path.join(data_path, f'{nickname}.csv'))

# %%
import streamlit as st

st.altair_chart(final_choice)
# Out:
# 2025-10-22 10:16:43.427 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 10:16:43.970
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\franc\OneDrive\Desktop\Magistrale\Cybersecurity Lab\01_EPSS\Lab1\venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-10-22 10:16:43.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 10:16:43.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
